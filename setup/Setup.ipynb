# %%
# 1. apaga o petraai (vazio, sem dó)
spark.sql("DROP CATALOG IF EXISTS petraai CASCADE")

# 2. recria com o nome final — e NUNCA MAIS troca
CATALOG = "itvalley_dev"
spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.silver")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.gold")

# %%
CATALOG = "petra-ai"

spark.sql(f"DROP CATALOG IF EXISTS `petra-ai` CASCADE")
